# %% [markdown]
# # Bonus: Temperature Analysis I

# %%
import pandas as pd
from datetime import datetime as dt

# %%
# "tobs" is "temperature observations"
df = pd.read_csv('Resources/hawaii_measurements.csv')
df.head()
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74
# 3  USC00519397  2010-01-04  0.00    76
# 4  USC00519397  2010-01-06   NaN    73

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19550 entries, 0 to 19549
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   station  19550 non-null  object
#  1   date     19550 non-null  object
#  2   prcp     18103 non-null  float64
#  3   tobs     19550 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 611.1+ KB

# %%
# Convert the date column format from string to datetime
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19550 entries, 0 to 19549
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   station  19550 non-null  object
#  1   date     19550 non-null  datetime64[ns]
#  2   prcp     18103 non-null  float64
#  3   tobs     19550 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 611.1+ KB

# %%
# Set the date column as the DataFrame index
df.set_index("date", inplace=True,)
df.sort_index(ascending = True)
# Out:
#                 station  prcp  tobs
# date
# 2010-01-01  USC00519397  0.08    65
# 2010-01-01  USC00518838  0.21    72
# 2010-01-01  USC00519523  0.15    75
# 2010-01-01  USC00519281  0.15    70
# 2010-01-01  USC00511918  0.05    66
# ...                 ...   ...   ...
# 2017-08-22  USC00516128  0.50    76
# 2017-08-23  USC00519397  0.00    81
# 2017-08-23  USC00514830  0.00    82
# 2017-08-23  USC00519523  0.08    82
# 2017-08-23  USC00516128  0.45    76
#
# [19550 rows x 3 columns]

# %% [markdown]
# ### Compare June and December data across all years

# %%
from scipy import stats

# %%
# Filter data for desired months # Filter by month in index directly
June = df[df.index.month == 6]
June
# Out:
#                 station  prcp  tobs
# date
# 2010-06-01  USC00519397  0.00    78
# 2010-06-02  USC00519397  0.01    76
# 2010-06-03  USC00519397  0.00    78
# 2010-06-04  USC00519397  0.00    76
# 2010-06-05  USC00519397  0.00    77
# ...                 ...   ...   ...
# 2017-06-26  USC00516128  0.02    79
# 2017-06-27  USC00516128  0.10    74
# 2017-06-28  USC00516128  0.02    74
# 2017-06-29  USC00516128  0.04    76
# 2017-06-30  USC00516128  0.20    75
#
# [1700 rows x 3 columns]

# %%
Dec = df[df.index.month == 12]
Dec
# Out:
#                 station  prcp  tobs
# date
# 2010-12-01  USC00519397  0.04    76
# 2010-12-03  USC00519397  0.00    74
# 2010-12-04  USC00519397  0.00    74
# 2010-12-06  USC00519397  0.00    64
# 2010-12-07  USC00519397  0.00    64
# ...                 ...   ...   ...
# 2016-12-27  USC00516128  0.14    71
# 2016-12-28  USC00516128  0.14    71
# 2016-12-29  USC00516128  1.03    69
# 2016-12-30  USC00516128  2.37    65
# 2016-12-31  USC00516128  0.90    65
#
# [1517 rows x 3 columns]

# %%
# Identify the average temperature for June # 74.944118
June.describe()
# Out:
#               prcp         tobs
# count  1574.000000  1700.000000
# mean      0.136360    74.944118
# std       0.335731     3.257417
# min       0.000000    64.000000
# 25%       0.000000    73.000000
# 50%       0.020000    75.000000
# 75%       0.120000    77.000000
# max       4.430000    85.000000

# %%
# Identify the average temperature for December # 71.041529
Dec.describe()
# Out:
#               prcp         tobs
# count  1405.000000  1517.000000
# mean      0.216819    71.041529
# std       0.541399     3.745920
# min       0.000000    56.000000
# 25%       0.000000    69.000000
# 50%       0.030000    71.000000
# 75%       0.150000    74.000000
# max       6.420000    83.000000

# %%
# Create collections of temperature data
June_temp = June['tobs'].to_list()
Dec_temp = Dec['tobs'].to_list()

# %%
# Since the lengths of the tobs list are different between June and Dec so can not run paired ttest. I am running unpaired indepedent t-test below. 
from scipy import stats
stats.ttest_ind(June_temp, Dec_temp)
# Out:
# Ttest_indResult(statistic=31.60372399000329, pvalue=3.9025129038616655e-191)

# %% [markdown]
# ### Analysis

# %% [markdown]
# # In years 2010-2017, the mean temp in June and Dec differs by 3.9F. Then, an unpaired t-test was conducted. With an extremely low p-value, the difference is deemed statistically significant.
